# %% [markdown]
# # 5. K-means

# %%
import os
os.environ['OMP_NUM_THREADS'] = '1'

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('KMeansData.csv')

# %%
dataset.head()
# Out:
#    hour  score
# 0  7.33     73
# 1  3.71     55
# 2  3.43     55
# 3  3.06     89
# 4  3.33     79

# %%
X = dataset.iloc[:,:].values
# X = dataset.values
# X = dataset.to_numpy() # 공식 홈페이지 권장
X[:5]
# Out:
# array([[ 7.33, 73.  ],
#        [ 3.71, 55.  ],
#        [ 3.43, 55.  ],
#        [ 3.06, 89.  ],
#        [ 3.33, 79.  ]])

# %% [markdown]
# ### 데이터 시각화 (전체 데이터 분포 확인)

# %%
plt.scatter(X[:,0],X[:,1]) # X축은 hours, y축은 score
plt.title('score by hours')
plt.xlabel('hours')
plt.ylabel('score')
plt.show()

# %% [markdown]
# ### 데이터 시각화 (축 범위 통일)

# %%
plt.scatter(X[:,0],X[:,1]) # X축은 hours, y축은 score
plt.title('score by hours')
plt.xlabel('hours')
plt.xlim(0,100)
plt.ylabel('score')
plt.ylim(0,100)
plt.show()

# %% [markdown]
# ### 피처 스케일링 (feature scaling)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)
X[:5]
# Out:
# array([[ 0.68729921,  0.73538376],
#        [-0.66687438,  0.04198891],
#        [-0.77161709,  0.04198891],
#        [-0.9100271 ,  1.35173473],
#        [-0.8090252 ,  0.96651537]])

# %% [markdown]
# ### 데이터 시각화 ( 스케일링된 데이터)

# %%
plt.figure(figsize=(5,5))
plt.scatter(X[:,0],X[:,1]) 
plt.title('score by hours')
plt.xlabel('hours')
plt.ylabel('score')
plt.show()

# %% [markdown]
# ### 최적의 k값 찾기(엘보우 방식 Elbow Method)

# %%
from sklearn.cluster import KMeans

inertia_list = []

for i in range(1,11):
    kmeans = KMeans(n_clusters=i, init='k-means++',random_state=0,n_init=10)
    kmeans.fit(X)
    inertia_list.append(kmeans.inertia_) # 각 지점으로부터 클러스터의 중심 까지의 거리의 제곱의 합
    
plt.plot(range(1,11),inertia_list)
plt.title("elbow method")
plt.xlabel('n_clusters')
plt.ylabel('inertia')
plt.show() # 최적의 k값 4

# %% [markdown]
# ### 최적의 K 값 으로 kmeans 학습

# %%
K = 4 # 최적의 k값

# %%
kmeans = KMeans(n_clusters=K,random_state=0,n_init=10)
# kmeans.fit(X)

y_kmeans = kmeans.fit_predict(X)

# %%
y_kmeans
# Out:
# array([2, 3, 3, 0, 0, 1, 1, 0, 2, 0, 0, 3, 1, 3, 3, 0, 1, 2, 3, 0, 1, 0,
#        3, 1, 2, 2, 3, 3, 3, 3, 1, 1, 3, 0, 2, 2, 3, 0, 0, 0, 3, 1, 2, 3,
#        3, 2, 1, 0, 1, 1, 2, 0, 1, 1, 0, 0, 0, 0, 3, 1, 1, 2, 2, 2, 2, 1,
#        1, 0, 1, 2, 3, 2, 2, 2, 3, 3, 3, 3, 0, 2, 1, 2, 1, 1, 2, 0, 3, 1,
#        2, 3, 0, 1, 0, 2, 3, 2, 2, 0, 1, 3], dtype=int32)

# %% [markdown]
# ### 데이터 시각화 (최적의 k)

# %%
centers = kmeans.cluster_centers_
centers # 클러스터의 중심점의 좌표
# Out:
# array([[-0.57163957,  0.85415973],
#        [ 0.8837666 , -1.26929779],
#        [ 0.94107583,  0.93569782],
#        [-1.22698889, -0.46768593]])

# %%
for cluster in range(K):
    plt.scatter(X[y_kmeans==cluster, 0],X[y_kmeans== cluster,1],s=100,edgecolors='black') # 각데이터 출력
    plt.scatter(centers[cluster, 0], centers[cluster,1],s=300, edgecolors='black',color='yellow',marker='s') # 중심점 출력
    plt.text(centers[cluster, 0], centers[cluster,1], cluster, va = 'center',ha='center') #텍스트 출력
    
plt.title('score by hours')
plt.xlabel('hours')
plt.ylabel('score')
plt.show()

# %% [markdown]
# ### 데이터 시각화(스케일링 원복)

# %%
X_org = sc.inverse_transform(X) #  피처 스케일링된 데이터를 다시 원복
X_org[:5]
# Out:
# array([[ 7.33, 73.  ],
#        [ 3.71, 55.  ],
#        [ 3.43, 55.  ],
#        [ 3.06, 89.  ],
#        [ 3.33, 79.  ]])

# %%
centers_org = sc.inverse_transform(centers)
centers_org
# Out:
# array([[ 3.96458333, 76.08333333],
#        [ 7.8552    , 20.96      ],
#        [ 8.0084    , 78.2       ],
#        [ 2.21269231, 41.76923077]])

# %%
for cluster in range(K):
    plt.scatter(X_org[y_kmeans==cluster, 0],X_org[y_kmeans== cluster,1],s=100,edgecolors='black') # 각데이터 출력
    plt.scatter(centers_org[cluster, 0], centers_org[cluster,1],s=300, edgecolors='black',color='yellow',marker='s') # 중심점 출력
    plt.text(centers_org[cluster, 0], centers_org[cluster,1], cluster, va = 'center',ha='center') #텍스트 출력
    
plt.title('score by hours')
plt.xlabel('hours')
plt.ylabel('score')
plt.show()
