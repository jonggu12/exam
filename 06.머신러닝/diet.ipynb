# %%
import pandas as pd
import numpy as np
train = pd.read_csv('online_diet.csv')

# %%
train.head()
# Out:
#    Unnamed: 0  seq_num        id  social_id1 zip_code  occupation  sex  \
# 0           0       28  webinner    740101.0  137-070         6.0  1.0
# 1           1       29  webinner    740101.0  137-070         6.0  1.0
# 2           2       30  webinner    740101.0  137-070         6.0  1.0
# 3           3       31  webinner    740101.0  137-070         6.0  1.0
# 4           4       32  webinner    740101.0  137-070         6.0  1.0
#
#    height  weight  married  ... loss_part  diet_purpose diet   bmi order_id  \
# 0   170.0    62.0      0.0  ...      1, 2           3.0    4  21.0    16560
# 1   170.0    62.0      0.0  ...      1, 2           3.0    4  21.0    16926
# 2   170.0    62.0      0.0  ...      1, 2           3.0    4  21.0    16941
# 3   170.0    62.0      0.0  ...      1, 2           3.0    4  21.0    16944
# 4   170.0    62.0      0.0  ...      1, 2           3.0    4  21.0    16967
#
#          pfid                 p_name p_price            p_created  p_quantity
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4458 entries, 0 to 4457
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    4458 non-null   int64
#  1   seq_num       4458 non-null   int64
#  2   id            4458 non-null   object
#  3   social_id1    4457 non-null   float64
#  4   zip_code      4456 non-null   object
#  5   occupation    4456 non-null   float64
#  6   sex           4456 non-null   float64
#  7   height        4456 non-null   float64
#  8   weight        4456 non-null   float64
#  9   married       4456 non-null   float64
#  10  dise          2930 non-null   object
#  11  want_diet     4456 non-null   float64
#  12  created       4458 non-null   object
#  13  waist         3135 non-null   object
#  14  heap          1899 non-null   object
#  15  loss_part     4206 non-null   object
#  16  diet_purpose  4183 non-null   float64
#  17  diet          3411 non-null   object
# ...

# %%
# 1.시간 데이터 object를 datetime으로 변환
