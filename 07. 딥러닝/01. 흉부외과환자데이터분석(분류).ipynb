# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

import numpy as np
import tensorflow as tf

np.random.seed(3)
tf.random.set_seed(3)


# 수술 데이터 환자 데이터 불러오기
Data_set = np.loadtxt('./data/ThoraricSurgery.csv', delimiter=',')

# %%
Data_set.shape # 행 470개, 열 18개
# Out:
# (470, 18)

# %%
# 환자의 기록과 수술 결과를 X와 y로 구분하여 저장

# 총 18개 0~17 X, 18 y

X = Data_set[:, 0:17] # 행은 모두, 0:17까지 컬럼
y = Data_set[:, 17] # 행은 모두, 17만 컬럼

# 딥러닝 구조 만들기 (모델 설정) (아직 값을 넣은건 아님, 모델만 만드는 작업)
model = Sequential()
model.add(Dense(30,input_dim =17,activation='relu')) # input_dim -> 입력레이어 , relu: 입력값 x가 0보다 크면 그 값을 그대로 출력하고, 0 이하이면 0을 출력
model.add(Dense(1,activation='sigmoid')) # 만약에 softmax라면 다중분류


# 딥러닝 학습(실행)
                    # 바이너리 = 이진분류	    최적화 알고리즘         성능측정지표
model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy']) # loss = 'categorical_crossentorypy' -> 다중분류
model.fit(X,y,epochs=100,batch_size=10) # epochs=100 -> 전체 모델 반복학습 횟수 , batch_size -> 10개씩 끊어서 데이터에 넣음


print('\n Accuracy: {0:.4f}'.format(model.evaluate(X,y)[1]))
# [0]: loss값 , [1]: 정확도
# Out:
# Epoch 1/100
# 47/47 [==============================] - 0s 843us/step - loss: 6.2728 - accuracy: 0.5936
# Epoch 2/100
# 47/47 [==============================] - 0s 699us/step - loss: 1.1704 - accuracy: 0.8021
# Epoch 3/100
# 47/47 [==============================] - 0s 595us/step - loss: 0.8482 - accuracy: 0.7979
# Epoch 4/100
# 47/47 [==============================] - 0s 755us/step - loss: 0.6879 - accuracy: 0.7894
# Epoch 5/100
# 47/47 [==============================] - 0s 639us/step - loss: 0.5159 - accuracy: 0.8298
# Epoch 6/100
# 47/47 [==============================] - 0s 547us/step - loss: 0.4464 - accuracy: 0.8404
# Epoch 7/100
# 47/47 [==============================] - 0s 512us/step - loss: 0.4512 - accuracy: 0.8489
# Epoch 8/100
# 47/47 [==============================] - 0s 469us/step - loss: 0.4456 - accuracy: 0.8532
# Epoch 9/100
# 47/47 [==============================] - 0s 486us/step - loss: 0.4286 - accuracy: 0.8532
# Epoch 10/100
# ...
