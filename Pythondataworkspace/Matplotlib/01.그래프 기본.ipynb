# %% [markdown]
# # Matplotlib
#
# 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. 그래프 기본

# %%
x = [1,2,3]
y = [2,4,8]
plt.plot(x,y)

# %%
print(plt.plot(x,y))
# Out:
# [<matplotlib.lines.Line2D object at 0x10f1dbc50>]

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## 제목 타이틀 설정

# %%
plt.plot(x,y)
plt.title('line Graph')
# Out:
# Text(0.5, 1.0, 'line Graph')

# %%
plt.plot(x,y)
plt.title('꺾은 선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은 선 그래프')
# /Users/choejong-gyu/anaconda3/lib/python3.11/site-packages/IPython/core/events.py:93: UserWarning: Glyph 44734 (\N{HANGUL SYLLABLE GGEOGG}) missing from current font.
#   func(*args, **kwargs)
# /Users/choejong-gyu/anaconda3/lib/python3.11/site-packages/IPython/core/events.py:93: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from current font.
#   func(*args, **kwargs)
# /Users/choejong-gyu/anaconda3/lib/python3.11/site-packages/IPython/core/events.py:93: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   func(*args, **kwargs)
# /Users/choejong-gyu/anaconda3/lib/python3.11/site-packages/IPython/core/events.py:93: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   func(*args, **kwargs)
# /Users/choejong-gyu/anaconda3/lib/python3.11/site-packages/IPython/core/events.py:93: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   func(*args, **kwargs)
# /Users/choejong-gyu/anaconda3/lib/python3.11/site-packages/IPython/core/events.py:93: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from current font.
#   func(*args, **kwargs)
# /Users/choejong-gyu/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44734 (\N{HANGUL SYLLABLE GGEOGG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/choejong-gyu/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/choejong-gyu/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/choejong-gyu/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/choejong-gyu/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/choejong-gyu/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 한글 폰트 설정

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'AppleGothic' 

matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.font_manager as fm

fm.fontManager.ttflist
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['STIXNonUnicode',
#  'STIXSizeOneSym',
#  'DejaVu Sans',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'STIXSizeFourSym',
#  'DejaVu Serif',
#  'STIXSizeFiveSym',
#  'cmex10',
#  'STIXSizeThreeSym',
#  'cmsy10',
#  'DejaVu Serif',
#  'cmss10',
#  'cmmi10',
#  'STIXNonUnicode',
#  'STIXSizeTwoSym',
#  'DejaVu Sans Display',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'cmr10',
#  'cmtt10',
#  'STIXGeneral',
#  'DejaVu Serif Display',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'cmb10',
#  'STIXSizeFourSym',
#  'STIXSizeThreeSym',
#  'DejaVu Sans Mono',
#  'STIXSizeTwoSym',
#  'DejaVu Sans',
#  'STIXSizeOneSym',
#  'Snell Roundhand',
#  'Times',
#  'Apple SD Gothic Neo',
#  'Noto Sans Inscriptional Parthian',
#  'STIXSizeTwoSym',
#  'Oriya MN',
#  'Arial Unicode MS',
#  'Big Caslon',
#  'PT Sans',
#  'Trebuchet MS',
#  'Avenir',
#  'Kokonor',
#  'Courier New',
#  'Arial Narrow',
#  'Noto Sans Hanunoo',
#  'Superclarendon',
#  'Hiragino Sans',
#  '.SF Compact Rounded',
#  'Noto Sans Nabataean',
#  'Microsoft Sans Serif',
#  'Noto Sans Old Italic',
#  'Noto Sans Buginese',
#  'Oriya Sangam MN',
#  'Verdana',
#  'Verdana',
#  'Kohinoor Gujarati',
#  'Noto Sans Old North Arabian',
#  'Bangla MN',
#  'Noto Sans Kharoshthi',
#  'Arial Hebrew',
#  'STIXIntegralsSm',
#  'Helvetica Neue',
#  'Noto Sans Thaana',
#  'Trebuchet MS',
#  'PT Mono',
#  'Arial Narrow',
#  'Tamil MN',
#  'Noto Sans Rejang',
#  'Hiragino Sans',
#  'Kohinoor Bangla',
#  'Trattatello',
#  'Noto Sans Manichaean',
#  'Noto Serif Myanmar',
#  'STIXNonUnicode',
#  'Noto Sans Cham',
#  '.Keyboard',
#  'Bodoni Ornaments',
#  'Noto Sans Sundanese',
#  'Myanmar MN',
#  '.Aqua Kana',
#  'Impact',
#  'Noto Sans Tai Viet',
#  'Gujarati MT',
#  'STIXIntegralsUpD',
#  'STIXIntegralsD',
#  'Gurmukhi MT',
#  'Malayalam MN',
#  'STIXSizeThreeSym',
#  'PT Serif',
#  'Telugu MN',
#  'Noto Sans Inscriptional Pahlavi',
#  'Mshtakan',
#  'Verdana',
#  'STIXVariants',
#  'STIXIntegralsUpD',
#  'Apple Braille',
#  'Kannada MN',
#  'Arial Unicode MS',
#  'Noto Sans Oriya',
#  'Herculanum',
#  'STIXIntegralsUpSm',
#  'Arial Narrow',
#  '.New York',
#  'Noto Sans Wancho',
#  'Noto Sans Avestan',
#  'Noto Sans Tifinagh',
#  'Zapf Dingbats',
#  'Noto Sans Multani',
#  'Baskerville',
#  'InaiMathi',
#  'STIXSizeThreeSym',
#  'Courier New',
#  'Academy Engraved LET',
#  'Noto Sans Duployan',
#  'Beirut',
#  'Hiragino Maru Gothic Pro',
#  'Futura',
#  'Noto Sans Yi',
#  'Kohinoor Devanagari',
#  'Noto Sans Khudawadi',
#  'Noto Sans Meroitic',
#  'Symbol',
#  'Noto Sans Marchen',
#  'Mishafi Gold',
#  'DIN Condensed',
#  'Thonburi',
#  'Didot',
#  'Noto Sans Old Hungarian',
#  'Noto Sans Palmyrene',
#  'System Font',
#  'STIXIntegralsUp',
#  'Sukhumvit Set',
#  'Athelas',
#  'Hiragino Sans',
#  'Times New Roman',
#  'Noto Sans Caucasian Albanian',
#  'Farah',
#  'Noto Sans Tagbanwa',
#  'Georgia',
#  'STIXSizeFourSym',
#  'Noto Sans Tagalog',
#  'Hiragino Mincho ProN',
#  'Noto Sans Hanifi Rohingya',
#  'Noto Sans Javanese',
#  'Phosphate',
#  'Noto Sans Imperial Aramaic',
#  'Songti SC',
#  'Gill Sans',
#  'Apple Symbols',
#  'Noto Sans Glagolitic',
#  '.SF Compact',
#  'Noto Sans Psalter Pahlavi',
#  'Noto Sans Adlam',
#  'Noto Sans Lisu',
#  'Trebuchet MS',
#  'Noto Sans Egyptian Hieroglyphs',
#  'Arial Black',
#  'Noto Sans Runic',
#  'Skia',
#  'Verdana',
#  'Apple Braille',
#  'Farisi',
#  'Times New Roman',
#  'Noto Serif Balinese',
#  'Noto Sans Lydian',
#  'Noto Sans Lepcha',
#  'Geeza Pro',
#  'Gurmukhi Sangam MN',
#  'Noto Sans Chakma',
#  'Telugu Sangam MN',
#  'STIXVariants',
#  'Plantagenet Cherokee',
#  'AppleMyungjo',
#  'Noto Sans Mende Kikakui',
#  'Sinhala MN',
#  'Noto Sans Mongolian',
#  'Bodoni 72 Oldstyle',
#  'Noto Sans Linear B',
#  'STIXSizeOneSym',
#  'Kefa',
#  'Tamil Sangam MN',
#  'Lao MN',
#  'Noto Sans Brahmi',
#  'PingFang HK',
#  'Diwan Thuluth',
#  'Andale Mono',
#  'Arial Rounded MT Bold',
#  'Malayalam Sangam MN',
#  'Marker Felt',
#  'Waseem',
#  'ITF Devanagari',
#  'STIXNonUnicode',
#  'Bradley Hand',
#  'Noto Sans Siddham',
#  'Zapfino',
#  'Noto Sans Elbasan',
#  'Noto Sans Linear A',
#  'STIXNonUnicode',
#  'Chalkboard SE',
#  '.SF NS Mono',
#  'Noto Sans Pahawh Hmong',
#  'Chalkduster',
#  'Noto Sans Armenian',
#  'AppleGothic',
#  'Bodoni 72',
#  'Papyrus',
#  'Noto Sans Ogham',
#  'Nadeem',
#  'Noto Sans Warang Citi',
#  'Noto Sans Old Persian',
#  'Palatino',
#  'Noto Sans Saurashtra',
#  'Optima',
#  'Noto Sans Bamum',
#  'Times New Roman',
#  'Noto Sans Sharada',
#  'Noto Sans Osage',
#  'STIXGeneral',
#  'Courier New',
#  'STIXIntegralsUp',
#  'Al Nile',
#  'Menlo',
#  '.SF NS Rounded',
#  'Hiragino Sans',
#  'Noto Sans Cuneiform',
#  'STIXSizeFiveSym',
#  'Noto Serif Ahom',
#  'STIXSizeOneSym',
#  'Savoye LET',
#  'Brush Script MT',
#  'Georgia',
#  'Noto Sans Limbu',
#  'Noto Sans Old Permic',
#  'Arial Narrow',
#  'KufiStandardGK',
#  'Noto Sans Modi',
#  'Devanagari MT',
#  'Sathu',
#  'Noto Sans Old South Arabian',
#  'Noto Sans New Tai Lue',
#  'Noto Sans Bassa Vah',
#  'Muna',
#  'Noto Sans Meetei Mayek',
#  'Noto Nastaliq Urdu',
#  'Noto Sans Batak',
#  'Noteworthy',
#  '.Arabic UI Text',
#  'Noto Sans NKo',
#  'Comic Sans MS',
#  'Noto Sans Miao',
#  'Heiti TC',
#  '.Arabic UI Display',
#  'Seravek',
#  'Party LET',
#  'Noto Sans Mahajani',
#  'Al Bayan',
#  'Wingdings 3',
#  'Bodoni 72 Smallcaps',
#  'Webdings',
#  'Noto Sans Syriac',
#  'Noto Sans PhagsPa',
#  'Damascus',
#  'Avenir Next Condensed',
#  'Times New Roman',
#  'Noto Sans Bhaiksuki',
#  'Noto Sans Ol Chiki',
#  'Trebuchet MS',
#  'Noto Sans Tai Tham',
#  'Helvetica',
#  'Hiragino Sans GB',
#  'Hiragino Sans',
#  'STIXIntegralsUpSm',
#  'Noto Sans Gothic',
#  'STIXGeneral',
#  'Arial',
#  'Devanagari Sangam MN',
#  'Hiragino Sans',
#  'Luminari',
#  'Noto Sans Osmanya',
#  'Apple Braille',
#  'Copperplate',
#  'Kohinoor Telugu',
#  'Hiragino Sans',
#  '.SF Compact',
#  'Khmer MN',
#  'Noto Sans Ugaritic',
#  'Cochin',
#  'Silom',
#  'Noto Sans Syloti Nagri',
#  'Noto Sans Kayah Li',
#  'STIXSizeFourSym',
#  'Noto Sans Cypriot',
#  'Tahoma',
#  'Noto Sans Samaritan',
#  'Noto Sans Tai Le',
#  'Noto Sans Carian',
#  'Heiti TC',
#  'Mukta Mahee',
#  'Lao Sangam MN',
#  'Kannada Sangam MN',
#  'Noto Sans Khojki',
#  'Hiragino Sans',
#  'Georgia',
#  'Noto Sans Phoenician',
#  'Noto Sans Sora Sompeng',
#  'Khmer Sangam MN',
#  'Hiragino Sans',
#  'Georgia',
#  'Euphemia UCAS',
#  'Shree Devanagari 714',
#  'Noto Sans Old Turkic',
#  'DecoType Naskh',
#  'Hiragino Sans',
#  'STIXGeneral',
#  'SignPainter',
#  'Arial',
#  'Wingdings 2',
#  'Hoefler Text',
#  'Al Tarikh',
#  'Ayuthaya',
#  'Noto Sans Vai',
#  'STIXNonUnicode',
#  'System Font',
#  'Noto Sans Hatran',
#  'Noto Sans Mro',
#  'Sana',
#  'Rockwell',
#  'Gurmukhi MN',
#  'Noto Sans Pau Cin Hau',
#  'Krungthep',
#  'Noto Sans Tirhuta',
#  'Apple Braille',
#  'Chalkboard',
#  'Lucida Grande',
#  'Noto Sans Myanmar',
#  'Kailasa',
#  'PT Serif Caption',
#  'Charter',
#  'Iowan Old Style',
#  'Tahoma',
#  'Arial',
#  'Sinhala Sangam MN',
#  '.SF NS Mono',
#  'Noto Sans Takri',
#  'Diwan Kufi',
#  'Comic Sans MS',
#  'DIN Alternate',
#  'Gujarati Sangam MN',
#  'Galvji',
#  'STIXGeneral',
#  'New Peninim MT',
#  'Noto Sans Kannada',
#  'Mishafi',
#  'Hoefler Text',
#  'Noto Sans Newa',
#  'Avenir Next',
#  'Noto Sans Buhid',
#  'STIXIntegralsSm',
#  'Noto Sans Mandaic',
#  'Raanana',
#  'STIXSizeTwoSym',
#  'Noto Sans Coptic',
#  '.New York',
#  'Noto Sans Shavian',
#  'Myanmar Sangam MN',
#  'Marion',
#  'Apple Chancery',
#  'Bangla Sangam MN',
#  'American Typewriter',
#  'Noto Sans Kaithi',
#  'Wingdings',
#  'STIXIntegralsD',
#  'Baghdad',
#  'Courier New',
#  'Arial',
#  'Corsiva Hebrew',
#  'Noto Sans Lycian',
#  'Apple Braille']

# %%
plt.plot(x,y)
plt.title('꺾은 선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은 선 그래프')

# %%
plt.plot([-1,0,1],[-5,-1,2])
